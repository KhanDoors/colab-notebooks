# %% [markdown]
# <a href="https://colab.research.google.com/github/KhanDoors/colab-notebooks/blob/main/fredData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fredapi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import fredapi as fd
import plotly.express as px

# %% [markdown]
# https://www.youtube.com/watch?v=C-riTGr6lIE

# %%
fred=fd.Fred(api_key='insert api key here')

# %%
data = fred.search("Consumer Price Index for All Urban Consumers: All Items in U.S. City Average")

# %%
data.head(10)
# Out:
#                             id realtime_start realtime_end  \
# series id
# CPIAUCSL              CPIAUCSL     2023-02-20   2023-02-20
# CPIAUCNS              CPIAUCNS     2023-02-20   2023-02-20
# CUUS0000SA0        CUUS0000SA0     2023-02-20   2023-02-20
# APU0000708111    APU0000708111     2023-02-20   2023-02-20
# CPILFESL              CPILFESL     2023-02-20   2023-02-20
# CPILFENS              CPILFENS     2023-02-20   2023-02-20
# CUUS0000SA0L1E  CUUS0000SA0L1E     2023-02-20   2023-02-20
# APU0000FF1101    APU0000FF1101     2023-02-20   2023-02-20
# APU0000703112    APU0000703112     2023-02-20   2023-02-20
# APU0000702111    APU0000702111     2023-02-20   2023-02-20
#
#                                                             title  \
# series id
# CPIAUCSL        Consumer Price Index for All Urban Consumers: ...
# CPIAUCNS        Consumer Price Index for All Urban Consumers: ...
# CUUS0000SA0     Consumer Price Index for All Urban Consumers: ...
# ...
